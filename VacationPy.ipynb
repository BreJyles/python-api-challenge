# %% [markdown]
# # VacationPy
# ---
#
# ## Starter Code to Import Libraries and Load the Weather and Coordinates Data

# %%
# Dependencies and Setup
import hvplot.pandas
import pandas as pd
import requests

# Import API key
from api_keys import geoapify_key

# %%
# Load the CSV file created in Part 1 into a Pandas DataFrame
city_data_df = pd.read_csv("output_data/cities.csv")

# Display sample data
city_data_df.head()
# Out:
#    City_ID               City      Lat       Lng  Max Temp  Humidity  \
# 0        0  port-aux-francais -49.3500   70.2167      4.25        87
# 1        1         carutapera  -1.1950  -46.0200     25.47        82
# 2        2          santa ana  33.7456 -117.8678     27.37        79
# 3        3             bethel  41.3712  -73.4140     23.83        79
# 4        4          adamstown -25.0660 -130.1015     22.39        87
#
#    Cloudiness  Wind Speed Country        Date
# 0          91       12.35      TF  1720754522
# 1          39        3.07      BR  1720754523
# 2          20        4.12      US  1720754524
# 3          20        1.54      US  1720754369
# 4         100       10.83      PN  1720754527

# %% [markdown]
# ---
#
# ### Step 1: Create a map that displays a point for every city in the `city_data_df` DataFrame. The size of the point should be the humidity in each city.

# %%
# %%capture --no-display

# Configure the map plot
# YOUR CODE HERE
map_plot = city_data_df.hvplot.points(
    "Lng",
    "Lat",
    geo = True,
    size = "Humidity",
    scale = 1,
    color = "City",
    alpha = 0.5,
    tiles = "OSM",
    frame_width = 700,
    frame_height = 500
)

# Display the map
# YOUR CODE HERE
map_plot
# Out:
# :Overlay
#    .Tiles.I  :Tiles   [x,y]
#    .Points.I :Points   [Lng,Lat]   (City,Humidity)

# %% [markdown]
# ### Step 2: Narrow down the `city_data_df` DataFrame to find your ideal weather condition

# %%
# Narrow down cities that fit criteria and drop any results with null values
# YOUR CODE HERE
narrowed_cities = city_data_df.loc[
    (city_data_df["Max Temp"] < 27) & (city_data_df["Max Temp"] > 21) \
    & (city_data_df["Wind Speed"] < 4.5) \
    & (city_data_df["Cloudiness"] == 0)
]
# Drop any rows with null values 
# YOUR CODE HERE
narrowed_cities = narrowed_cities.dropna()
# Display sample data
# YOUR CODE HERE
narrowed_cities
# Out:
#      City_ID                        City      Lat       Lng  Max Temp  \
# 72        72                  andergrove -21.0833  149.1833     26.94
# 125      125                 noosa heads -26.3833  153.1500     23.52
# 163      163                      dryden  49.7833  -92.7503     23.16
# 198      198                     yorkton  51.2167 -102.4677     26.91
# 204      204                    westport  41.1415  -73.3579     24.79
# 224      224                    belmonte -15.8631  -38.8828     22.28
# 269      269                   mount isa -20.7333  139.5000     26.87
# 270      270               ribeira brava  32.6500  -17.0667     23.89
# 286      286             santa marinella  42.0345   11.8536     23.71
# 291      291                   cernavoda  44.3667   28.0167     24.58
# 342      342                richards bay -28.7830   32.0377     21.31
# 344      344                     kulunda  52.5660   78.9385     25.78
# 407      407                       edson  53.5835 -116.4356     22.08
# 408      408            brebu manastirei  45.1833   25.7667     21.25
# 447      447                    beaumont  30.0861  -94.1019     25.99
# 522      522                   barcelona  41.3888    2.1590     24.86
# 545      545                      waddan  29.1614   16.1390     24.98
# 560      560                   belyy yar  53.6039   91.3903     21.94
# 565      565                   brookings  44.3114  -96.7984     21.19
# 570      570  san sebastian de la gomera  28.0916  -17.1133     23.20
# 572      572           al fqih ben calah  32.5009   -6.6906     25.53
# 574      574                    mitchell  43.7094  -98.0298     23.42
# 577      577                    ciserano  45.5894    9.6026     24.65
#
#      Humidity  Cloudiness  Wind Speed Country        Date
# 72         69           0        2.96      AU  1720754618
# 125        54           0        1.41      AU  1720754687
# 163        68           0        3.60      CA  1720754739
# 198        78           0        3.60      CA  1720754784
# 204        80           0        2.06      US  1720754792
# 224        76           0        2.14      BR  1720754817
# 269        19           0        3.60      AU  1720754875
# 270        85           0        1.84      PT  1720754876
# 286        67           0        0.96      IT  1720754896
# 291        40           0        2.72      RO  1720754902
# 342        15           0        4.02      ZA  1720754701
# 344        54           0        1.83      RU  1720754843
# 407        30           0        3.60      CA  1720755049
# 408        43           0        3.60      RO  1720755050
# 447        98           0        0.00      US  1720755099
# 522        71           0        2.06      ES  1720755119
# 545        50           0        0.76      LY  1720755229
# 560        56           0        1.00      RU  1720755248
# 565        93           0        3.49      US  1720755256
# 570        78           0        2.57      ES  1720755262
# 572        48           0        2.17      MA  1720755265
# 574        68           0        4.02      US  1720755065
# 577        78           0        0.51      IT  1720755272

# %% [markdown]
# ### Step 3: Create a new DataFrame called `hotel_df`.

# %%
# Use the Pandas copy function to create DataFrame called hotel_df to store the city, country, coordinates, and humidity
# YOUR CODE HERE
hotel_df = narrowed_cities[["City", "Country", "Lat", "Lng", "Humidity"]].copy()
# Add an empty column, "Hotel Name," to the DataFrame so you can store the hotel found using the Geoapify API
# YOUR CODE HERE
hotel_df["Hotel Name"] = ""
# Display sample data
# YOUR CODE HERE
hotel_df
# Out:
#                            City Country      Lat       Lng  Humidity  \
# 72                   andergrove      AU -21.0833  149.1833        69
# 125                 noosa heads      AU -26.3833  153.1500        54
# 163                      dryden      CA  49.7833  -92.7503        68
# 198                     yorkton      CA  51.2167 -102.4677        78
# 204                    westport      US  41.1415  -73.3579        80
# 224                    belmonte      BR -15.8631  -38.8828        76
# 269                   mount isa      AU -20.7333  139.5000        19
# 270               ribeira brava      PT  32.6500  -17.0667        85
# 286             santa marinella      IT  42.0345   11.8536        67
# 291                   cernavoda      RO  44.3667   28.0167        40
# 342                richards bay      ZA -28.7830   32.0377        15
# 344                     kulunda      RU  52.5660   78.9385        54
# 407                       edson      CA  53.5835 -116.4356        30
# 408            brebu manastirei      RO  45.1833   25.7667        43
# 447                    beaumont      US  30.0861  -94.1019        98
# 522                   barcelona      ES  41.3888    2.1590        71
# 545                      waddan      LY  29.1614   16.1390        50
# 560                   belyy yar      RU  53.6039   91.3903        56
# 565                   brookings      US  44.3114  -96.7984        93
# 570  san sebastian de la gomera      ES  28.0916  -17.1133        78
# 572           al fqih ben calah      MA  32.5009   -6.6906        48
# 574                    mitchell      US  43.7094  -98.0298        68
# 577                    ciserano      IT  45.5894    9.6026        78
#
#     Hotel Name
# 72
# 125
# 163
# 198
# 204
# 224
# 269
# 270
# 286
# 291
# 342
# 344
# 407
# 408
# 447
# 522
# 545
# 560
# 565
# 570
# 572
# 574
# 577

# %% [markdown]
# ### Step 4: For each city, use the Geoapify API to find the first hotel located within 10,000 metres of your coordinates.

# %%
# Set parameters to search for a hotel
radius = 10000
geoapify_key = "c492c6dac14e4a43b94dd7cf23209f8e"
params = {
    "categories":"accommodation.hotel",
    "apiKey": geoapify_key,
    "limit": 20
}
   
# Print a message to follow up the hotel search
print("Starting hotel search")

# Iterate through the hotel_df DataFrame
for index, row in hotel_df.iterrows():
    latitude = row["Lat"]
    longitude = row["Lng"]
    

    # Add the current city's latitude and longitude to the params dictionary
    params["filter"] = f"circle:{longitude},{latitude},{radius}"
    params["bias"] = f"proximity:{longitude},{latitude}"
    # Set base URL
    base_url = "https://api.geoapify.com/v2/places"

    # Make and API request using the params dictionary
    name_address = requests.get(base_url, params=params)
    
    # Convert the API response to JSON format
    name_address = name_address.json()
    
    #hotel_df.loc[index, "Hotel Name"] = name_address["features"][2]["properties"]["name"]
     #Grab the first hotel from the results and store the name in the hotel_df DataFrame
    try:
        hotel_df.loc[index, "Hotel Name"] = name_address["features"][0]["properties"]["name"]
    except (KeyError, IndexError):
        #If no hotel is found, set the hotel name as "No hotel found".
        hotel_df.loc[index, "Hotel Name"] = "No hotel found"

    # Log the search results
    print(f"{hotel_df.loc[index, 'City']} - nearest hotel: {hotel_df.loc[index, 'Hotel Name']}")

# Display sample data
hotel_df
# Out:
# Starting hotel search
# andergrove - nearest hotel: No hotel found
# noosa heads - nearest hotel: Costa Nova Apartments
# dryden - nearest hotel: Holiday Inn Express
# yorkton - nearest hotel: Holiday Inn Express
# westport - nearest hotel: Norwalk Inn and Conference Center
# belmonte - nearest hotel: No hotel found
# mount isa - nearest hotel: Ibis Styles
# ribeira brava - nearest hotel: Cheerfulway Bravamar Hotel
# santa marinella - nearest hotel: Albergo Miramare
# cernavoda - nearest hotel: Daria
# richards bay - nearest hotel: SUN1 Richards Bay
# kulunda - nearest hotel: Вояж
# edson - nearest hotel: Best Western High Road Inn
# brebu manastirei - nearest hotel: Pensiunea Oscar Câmpina
# beaumont - nearest hotel: The Haunted Hotel
# barcelona - nearest hotel: Cram
# waddan - nearest hotel: No hotel found
# belyy yar - nearest hotel: No hotel found
# brookings - nearest hotel: Quality Inn
# san sebastian de la gomera - nearest hotel: Hotel Villa Gomera
# al fqih ben calah - nearest hotel: Hotel Oum Elfadl
# mitchell - nearest hotel: Quality Inn
# ciserano - nearest hotel: Palace Hotel
#                            City Country      Lat       Lng  Humidity  \
# 72                   andergrove      AU -21.0833  149.1833        69
# 125                 noosa heads      AU -26.3833  153.1500        54
# 163                      dryden      CA  49.7833  -92.7503        68
# 198                     yorkton      CA  51.2167 -102.4677        78
# 204                    westport      US  41.1415  -73.3579        80
# 224                    belmonte      BR -15.8631  -38.8828        76
# 269                   mount isa      AU -20.7333  139.5000        19
# 270               ribeira brava      PT  32.6500  -17.0667        85
# 286             santa marinella      IT  42.0345   11.8536        67
# 291                   cernavoda      RO  44.3667   28.0167        40
# 342                richards bay      ZA -28.7830   32.0377        15
# 344                     kulunda      RU  52.5660   78.9385        54
# 407                       edson      CA  53.5835 -116.4356        30
# 408            brebu manastirei      RO  45.1833   25.7667        43
# 447                    beaumont      US  30.0861  -94.1019        98
# 522                   barcelona      ES  41.3888    2.1590        71
# 545                      waddan      LY  29.1614   16.1390        50
# 560                   belyy yar      RU  53.6039   91.3903        56
# 565                   brookings      US  44.3114  -96.7984        93
# 570  san sebastian de la gomera      ES  28.0916  -17.1133        78
# 572           al fqih ben calah      MA  32.5009   -6.6906        48
# 574                    mitchell      US  43.7094  -98.0298        68
# 577                    ciserano      IT  45.5894    9.6026        78
#
#                             Hotel Name
# 72                      No hotel found
# 125              Costa Nova Apartments
# 163                Holiday Inn Express
# 198                Holiday Inn Express
# 204  Norwalk Inn and Conference Center
# 224                     No hotel found
# 269                        Ibis Styles
# 270         Cheerfulway Bravamar Hotel
# 286                   Albergo Miramare
# 291                              Daria
# 342                  SUN1 Richards Bay
# 344                               Вояж
# 407         Best Western High Road Inn
# 408            Pensiunea Oscar Câmpina
# 447                  The Haunted Hotel
# 522                               Cram
# 545                     No hotel found
# 560                     No hotel found
# 565                        Quality Inn
# 570                 Hotel Villa Gomera
# 572                   Hotel Oum Elfadl
# 574                        Quality Inn
# 577                       Palace Hotel

# %% [markdown]
# ### Step 5: Add the hotel name and the country as additional information in the hover message for each city in the map.

# %%
# %%capture --no-display
# Configure the map plot
map_plot = city_data_df.hvplot.points(
    "Lng",
    "Lat",
    geo = True,
    size = "Humidity",
    scale = 1,
    color = "City",
    alpha = 0.5,
    tiles = "OSM",
    frame_width = 700,
    frame_height = 500,
    hover_cols = ["Hotel Name", "Country"]
)

# Display the map
map_plot
# Out:
# :Overlay
#    .Tiles.I  :Tiles   [x,y]
#    .Points.I :Points   [Lng,Lat]   (City,Humidity,Country)
